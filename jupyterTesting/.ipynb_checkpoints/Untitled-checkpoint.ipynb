# %%
pathToTestCases = "../test/nossum"
pathToBuild = "../build"
pathToTestPre = "../testPre/nossum"

alltestfiles = !ls -Sr {pathToTestCases}

# %%
class SolveRes:
    def __init__(self, ret, name):
        self.log = ret
        self.name = name
        if(ret[-1].split()[-1] == "UNKNOWN"):
            self.res = "TIMEOUT"
            self.time = "TIMEOUT"
        else:
            self.res = ret[-2].split()[-1]
            self.time = ret[-1].split()[2]
    def prettyPrint(self):
        print("Solved problem:", self.name)
        print("Result:", self.res)
        print("Time:", self.time)

# %%
class PresolveOut:
    def __init__(self, preRet, name):
        self.name = name
        self.log = preRet
        try:
            self.time = preRet[-1].split()[2]
        except:
            selt.time = "TIMEOUT"
        try:    
            self.status = preRet[-2].split()[-1]
            #self.nrows = preRet[-5].split()[-1]
            #self.ncols = preRet[-4].split()[1]
        except:
            self.status = "TIMEOUT"
    def prettyPrint(self):
        print("Presolved problem:", self.name)
        print("Status:", self.status)
        print("Time:", self.time)

# %%
 class ComparePreAndBase:
    def __init__(self, res_base, res_withpre, stats_presolver, filename):
        self.name = filename
        self.res_base = res_base
        self.res_withpre = res_withpre
        self.stats_presolver = stats_presolver

# %%
def presolve(filename):
    ret = !gtimeout 3600 time {pathToBuild}/PresolveOpb {pathToTestCases}/{filename} {pathToTestPre}/pre.{filename}
    return PresolveOut(ret, filename)

# %%
def solve(filename, to_pre_or_not_to_pre):
    filenamestring = filename
    if(to_pre_or_not_to_pre):
        filenamestring = "pre." + filenamestring
        ret = !gtimeout 7200 time {pathToBuild}/roundingsat {pathToTestPre}/{filenamestring}
    else:
        ret = !gtimeout 7200 time {pathToBuild}/roundingsat {pathToTestCases}/{filenamestring}
    return SolveRes(ret, filenamestring)

# %%
alltestfiles[:20]
# Out:
# ['normalized-sha1-size80-round21-9.opb',
#  'normalized-sha1-size80-round21-8.opb',
#  'normalized-sha1-size80-round21-7.opb',
#  'normalized-sha1-size80-round21-6.opb',
#  'normalized-sha1-size80-round21-5.opb',
#  'normalized-sha1-size80-round21-4.opb',
#  'normalized-sha1-size80-round21-3.opb',
#  'normalized-sha1-size80-round21-2.opb',
#  'normalized-sha1-size80-round21-1.opb',
#  'normalized-sha1-size80-round21-0.opb',
#  'normalized-sha1-size96-round21-9.opb',
#  'normalized-sha1-size96-round21-8.opb',
#  'normalized-sha1-size96-round21-7.opb',
#  'normalized-sha1-size96-round21-6.opb',
#  'normalized-sha1-size96-round21-5.opb',
#  'normalized-sha1-size96-round21-4.opb',
#  'normalized-sha1-size96-round21-3.opb',
#  'normalized-sha1-size96-round21-2.opb',
#  'normalized-sha1-size96-round21-1.opb',
#  'normalized-sha1-size96-round21-0.opb']

# %%
quickProblems = ['air01.0.s.opb',
 'air01.0.u.opb',
 'air02.0.s.opb',
 'air02.0.u.opb',
 'bm23.0.s.opb',
 'bm23.0.u.opb',
 'diamond.0.d.opb',
 'p0040.0.s.opb',
 'p0040.0.u.opb',
 'p0291.0.s.opb',
 'p0291.0.u.opb',
 'pipex.0.s.opb',
 'pipex.0.u.opb',
 'sentoy.0.s.opb',
 'sentoy.0.u.opb',
 'stein15.0.s.opb',
 'stein15.0.u.opb',
 'stein9.0.s.opb',
 'stein9.0.u.opb']

# %%
logfile= "nossum.log1.json"

# %%
import json
i_iteration = 0
with open(logfile, "w") as outfile:
    outfile.write("[\n")

    for prob in alltestfiles[0:2]:
        print("i = " + str(i_iteration))
        i_iteration += 1
        jsonobj = {"name": prob }
        
        presolveinf = presolve(prob)
        presolveinf.prettyPrint()
        jsonobj['status'] = presolveinf.status
        jsonobj['presolveTime'] = float(presolveinf.time)

        if(presolveinf.status == "TIMEOUT"):
            for line in presolveinf.log:
                print(" " + line)

        if(presolveinf.status == "1"):
            solveres = solve(prob, False)
            print(" - solver time:       " + solveres.time)
            jsonobj['solverBaseTime'] = float(solveres.time)
            
            solverespre = solve(prob, True)
            print(" - solver time (pre): "+ solverespre.time)
            print(" - same result:", solveres.res == solverespre.res)
            jsonobj['solverPreTime'] = float(solverespre.time)
            jsonobj['sameRes'] = str(solveres.res == solverespre.res)
            
        #timediff = float(solveres.time[:-1]) - float(solverespre.time[:-1]) - float(presolveinf.time[:-1])
        outfile.write(json.dumps(jsonobj)+",\n")


        #print("solver time: " + solveres.time + "   solver time (pre): "+ solverespre.time)
        print()
    outfile.write("\n]")
# Out:
# i = 0
# Presolved problem: normalized-sha1-size80-round21-9.opb
# Status: 1
# Time: 3.83
#  - solver time:       387.83
# ^C
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-123-a7e1b87d0d99> in <module>
#      23             jsonobj['solverBaseTime'] = float(solveres.time)
#      24
# ---> 25             solverespre = solve(prob, True)
#      26             print(" - solver time (pre): "+ solverespre.time)
#      27             print(" - same result:", solveres.res == solverespre.res)
#
# <ipython-input-121-7078959e8a0d> in solve(filename, to_pre_or_not_to_pre)
#       6     else:
#       7         ret = get_ipython().getoutput('gtimeout 7200 time {pathToBuild}/roundingsat {pathToTestCases}/{filenamestring}')
# ----> 8     return SolveRes(ret, filenamestring)
#
# <ipython-input-112-332b3216d8e9> in __init__(self, ret, name)
#       3         self.log = ret
#       4         self.name = name
# ----> 5         if(ret[-1].split()[-1] == "UNKNOWN"):
#       6             self.res = "TIMEOUT"
#       7             self.time = "TIMEOUT"
#
# IndexError: list index out of range

# %%
logfile = "logfilePreSolvingOptProblems01.json"
alltestOpt = !ls ../testOpt

# %%
import json

with open(logfile, 'w') as outfile:
    outfile.write("[\n")
    for prob in alltestOpt:
        #solveres = solve(prob, False)
        #outfile.write(json.dumps(solveres.__dict__)+',\n')
        
        presolveout = presolve(prob)
        outfile.write(json.dumps(presolveout.__dict__)+',\n')
        
        #presolveres = solve(prob, True)
        #outfile.write(json.dumps(presolveres.__dict__)+',\n')
        
        print(prob)
        #print("Same result: "   + str(solveres.res == presolveres.res))
        print("Presolve time: " + presolveout.time)
        #print("solver res: "    + solveres.res  + "   solver res (pre): "  + presolveres.res)
        #print("solver time: "   + solveres.time + "   solver time (pre): " + presolveres.time)
        print()
    outfile.write("]")
# Out:
# air01.opb
# Presolve time: 0.09
#
# air02.opb
# Presolve time: 3.01
#
# air03.opb
# Presolve time: 3.42
#
# air04.opb
# Presolve time: 1.55
#
# air05.opb
# Presolve time: 0.97
#
# air06.opb
# Presolve time: 1.32
#
# bm23.opb
# Presolve time: 0.01
#
# cracpb1.opb
# Presolve time: 0.07
#
# diamond.opb
# Presolve time: 0.00
#
# enigma.opb
# Presolve time: 0.01
#
# l152lav.opb
# Presolve time: 0.17
#
# lp4l.opb
# Presolve time: 0.07
#
# lseu.opb
# Presolve time: 0.01
#
# mod008.opb
# Presolve time: 0.01
#
# mod010.opb
# Presolve time: 0.27
#
# normalized-single-obj-f47-DC-Side1.seq-B-2-1-EDCBAir.opb
# Presolve time: 0.00
#
# p0033.opb
# Presolve time: 0.00
#
# p0040.opb
# Presolve time: 0.01
#
# p0201.opb
# Presolve time: 0.02
#
# p0282.opb
# Presolve time: 0.03
#
# p0291.opb
# Presolve time: 0.02
#
# p0548.opb
# Presolve time: 0.04
#
# p2756.opb
# Presolve time: 0.18
#
# p6000.opb
# Presolve time: 0.77
#
# pipex.opb
# Presolve time: 0.01
#
# sentoy.opb
# Presolve time: 0.02
#
# stein15.opb
# Presolve time: 0.00
#
# stein27.opb
# Presolve time: 0.01
#
# stein45.opb
# Presolve time: 0.01
#
# stein9.opb
# Presolve time: 0.00

# %%
presolveout.log
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-124-b93426e5d73b> in <module>
# ----> 1 presolveout.log
#
# NameError: name 'presolveout' is not defined

# %%
# Out:
# ['Filename in given: ../test/nossum/normalized-sha1-size80-round21-9.opb Filename out given: ../testPre/nossum/pre.normalized-sha1-size80-round21-9.opb',
#  'Parsing ...',
#  '  Parser found: 3968 vars',
#  '  Parser found: 7856 constraints',
#  'Done!',
#  '',
#  'starting presolve of problem ../test/nossum/normalized-sha1-size80-round21-9.opb:',
#  '  rows:     7856',
#  '  columns:  3968 (3968 int., 0 cont.)',
#  '  nonzeros: 33164',
#  '',
#  'round 0   ( Trivial  ):  456 del cols,  992 del rows,  456 chg bounds,    0 chg sides,    0 chg coeffs,    0 tsx applied,    0 tsx conflicts',
#  'round 1   (   Fast   ):  620 del cols,  993 del rows,  508 chg bounds,  112 chg sides,  112 chg coeffs,  164 tsx applied,    0 tsx conflicts',
#  'round 2   (   Fast   ):  654 del cols, 1076 del rows,  542 chg bounds,  112 chg sides,  112 chg coeffs,  182 tsx applied,    0 tsx conflicts',
#  'round 3   (   Fast   ):  677 del cols, 1137 del rows,  562 chg bounds,  115 chg sides,  115 chg coeffs,  192 tsx applied,    0 tsx conflicts',
#  'round 4   (   Fast   ):  684 del cols, 1142 del rows,  568 chg bounds,  116 chg sides,  116 chg coeffs,  196 tsx applied,    0 tsx conflicts',
#  'round 5   (   Fast   ):  688 del cols, 1150 del rows,  571 chg bounds,  117 chg sides,  117 chg coeffs,  199 tsx applied,    0 tsx conflicts',
#  'round 6   (   Fast   ):  691 del cols, 1153 del rows,  574 chg bounds,  117 chg sides,  117 chg coeffs,  200 tsx applied,    0 tsx conflicts',
#  'round 7   (  Medium  ):  760 del cols, 1199 del rows,  575 chg bounds,  117 chg sides,  963 chg coeffs,  276 tsx applied,    0 tsx conflicts',
#  'round 8   (  Medium  ):  766 del cols, 1203 del rows,  575 chg bounds,  159 chg sides, 1127 chg coeffs,  282 tsx applied,    2 tsx conflicts',
#  'round 9   (Exhaustive):  829 del cols, 1291 del rows,  577 chg bounds,  471 chg sides, 2032 chg coeffs,  359 tsx applied,   52 tsx conflicts',
#  'round 10  (Exhaustive):  832 del cols, 1292 del rows,  577 chg bounds,  476 chg sides, 2041 chg coeffs,  363 tsx applied,   56 tsx conflicts',
#  'activating delayed presolvers',
#  'round 11  (Exhaustive):  833 del cols, 1293 del rows,  577 chg bounds,  476 chg sides, 2085 chg coeffs,  365 tsx applied,   59 tsx conflicts',
#  'round 12  (  Final   ): Unchanged',
#  'presolved 12 rounds:  833 del cols, 1293 del rows,  577 chg bounds,  476 chg sides, 2085 chg coeffs,  365 tsx applied,   60 tsx conflicts',
#  '',
#  '          presolver     nb calls   success calls(%)    nb transactions     tsx applied(%)  execution time(s) ',
#  '       colsingleton           12               41.7                118              100.0              0.000',
#  '    coefftightening           12                0.0                  0                0.0              0.001',
#  '        propagation           12               50.0                 83              100.0              0.001',
#  '      simpleprobing            4               50.0                 62              100.0              0.000',
#  '           stuffing            3                0.0                  0                0.0              0.001',
#  '            dualfix            3                0.0                  0                0.0              0.002',
#  '      fixcontinuous            0                0.0                  0                0.0              0.000',
#  '       parallelrows            0                0.0                  0                0.0              0.000',
#  '       parallelcols            0                0.0                  0                0.0              0.000',
#  '        doubletoneq            6               83.3                 26               76.9              0.002',
#  '       simplifyineq            3                0.0                  0                0.0              0.010',
#  '            implint            0                0.0                  0                0.0              0.000',
#  '          dualinfer            0                0.0                  0                0.0              0.000',
#  '       substitution            4              100.0                 67               19.4              0.029',
#  '            probing            4               75.0                 69              100.0              0.551',
#  '             domcol            2                0.0                  0                0.0              0.005',
#  '           sparsify            1                0.0                  0                0.0              0.002',
#  '',
#  'presolved problem:',
#  '  rows:     6563',
#  '  columns:  3135 (3135 int., 0 cont.)',
#  '  nonzeros: 28489',
#  'Status code of test problem: 1',
#  '        0.88 real         3.83 user         0.06 sys']

# %%
float(presolveres.time[:-1])
# Out:
# 4.53

# %%
solveres
# Out:
# ['c RoundingSat 2',
#  'c branch master',
#  'c commit 1476bf0',
#  'c #variables 572 #constraints 216',
#  'c #Conflicts:       1000 | #Constraints:       1215',
#  'c #Conflicts:       2000 | #Constraints:       2215',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:       3000 | #Constraints:       2062',
#  'c #Conflicts:       4000 | #Constraints:       3062',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:       5000 | #Constraints:       2236',
#  'c #Conflicts:       6000 | #Constraints:       3236',
#  'c #Conflicts:       7000 | #Constraints:       4236',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:       8000 | #Constraints:       2773',
#  'c #Conflicts:       9000 | #Constraints:       3773',
#  'c #Conflicts:      10000 | #Constraints:       4773',
#  'c #Conflicts:      11000 | #Constraints:       5773',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:      12000 | #Constraints:       3940',
#  'c #Conflicts:      13000 | #Constraints:       4940',
#  'c #Conflicts:      14000 | #Constraints:       5940',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:      15000 | #Constraints:       3922',
#  'c #Conflicts:      16000 | #Constraints:       4922',
#  'c #Conflicts:      17000 | #Constraints:       5922',
#  'c #Conflicts:      18000 | #Constraints:       6922',
#  'c #Conflicts:      19000 | #Constraints:       7922',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:      20000 | #Constraints:       4992',
#  'c #Conflicts:      21000 | #Constraints:       5992',
#  'c #Conflicts:      22000 | #Constraints:       6992',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:      23000 | #Constraints:       4395',
#  'c #Conflicts:      24000 | #Constraints:       5395',
#  'c #Conflicts:      25000 | #Constraints:       6395',
#  'c #Conflicts:      26000 | #Constraints:       7395',
#  'c #Conflicts:      27000 | #Constraints:       8395',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:      28000 | #Constraints:       5244',
#  'c #Conflicts:      29000 | #Constraints:       6244',
#  'c #Conflicts:      30000 | #Constraints:       7244',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:      31000 | #Constraints:       4227',
#  'c #Conflicts:      32000 | #Constraints:       5227',
#  'c #Conflicts:      33000 | #Constraints:       6227',
#  'c #Conflicts:      34000 | #Constraints:       7227',
#  'c #Conflicts:      35000 | #Constraints:       8227',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:      36000 | #Constraints:       5157',
#  'c #Conflicts:      37000 | #Constraints:       6157',
#  'c #Conflicts:      38000 | #Constraints:       7157',
#  'c #Conflicts:      39000 | #Constraints:       8157',
#  'c #Conflicts:      40000 | #Constraints:       9157',
#  'c #Conflicts:      41000 | #Constraints:      10157',
#  'c #Conflicts:      42000 | #Constraints:      11157',
#  'c #Conflicts:      43000 | #Constraints:      12157',
#  'c #Conflicts:      44000 | #Constraints:      13157',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:      45000 | #Constraints:       7322',
#  'c #Conflicts:      46000 | #Constraints:       8322',
#  'c #Conflicts:      47000 | #Constraints:       9322',
#  'c #Conflicts:      48000 | #Constraints:      10322',
#  'c #Conflicts:      49000 | #Constraints:      11322',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:      50000 | #Constraints:       6652',
#  'c #Conflicts:      51000 | #Constraints:       7652',
#  'c #Conflicts:      52000 | #Constraints:       8652',
#  'c #Conflicts:      53000 | #Constraints:       9652',
#  'c #Conflicts:      54000 | #Constraints:      10652',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:      55000 | #Constraints:       6065',
#  'c #Conflicts:      56000 | #Constraints:       7065',
#  'c #Conflicts:      57000 | #Constraints:       8065',
#  'c #Conflicts:      58000 | #Constraints:       9065',
#  'c #Conflicts:      59000 | #Constraints:      10065',
#  'c #Conflicts:      60000 | #Constraints:      11065',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:      61000 | #Constraints:       6269',
#  'c #Conflicts:      62000 | #Constraints:       7269',
#  'c #Conflicts:      63000 | #Constraints:       8269',
#  'c #Conflicts:      64000 | #Constraints:       9269',
#  'c Program interrupted by user.',
#  'c cpu time 29.1176 s',
#  'c deterministic time 3127508461 3.13e+09',
#  'c optimization time 1.51303 s',
#  'c total solve time 27.6006 s',
#  'c propagation time 21.2252 s',
#  'c conflict analysis time 6.87584 s',
#  'c propagations 3606806',
#  'c resolve steps 271713',
#  'c decisions 350473',
#  'c conflicts 64413',
#  'c restarts 193',
#  'c inprocessing phases 14',
#  'c input clauses 58',
#  'c input cardinalities 153',
#  'c input general constraints 5',
#  'c input average constraint length 31.42',
#  'c input average constraint degree 2468.55',
#  'c learned clauses 5806',
#  'c learned cardinalities 699',
#  'c learned general constraints 57908',
#  'c learned average constraint length 213.95',
#  'c learned average constraint degree 162519.63',
#  'c watched constraints 22014',
#  'c counting constraints 35899',
#  'c gcd simplifications 442',
#  'c detected cardinalities 13',
#  'c weakened non-implied lits 5369459',
#  'c weakened non-implying lits 5811',
#  'c original variables 572',
#  'c clausal propagations 101151',
#  'c cardinality propagations 1236230',
#  'c watched propagations 192575',
#  'c counting propagations 1994379',
#  'c watch lookups 683431642',
#  'c watch backjump lookups 672775325',
#  'c watch checks 570038902',
#  'c propagation checks 1139683907',
#  'c constraint additions 53600231',
#  'c trail pops 4021174',
#  'c formula constraints 216',
#  'c learned constraints 64413',
#  'c bound constraints 0',
#  'c encountered formula constraints 108987',
#  'c encountered learned constraints 227139',
#  'c encountered bound constraints 0',
#  'c LP total time 0 s',
#  'c LP solve time 0 s',
#  'c LP constraints added 0',
#  'c LP constraints removed 0',
#  'c LP pivots internal 0',
#  'c LP pivots root 0',
#  'c LP calls 0',
#  'c LP optimalities 0',
#  'c LP no pivot count 0',
#  'c LP infeasibilities 0',
#  'c LP valid Farkas constraints 0',
#  'c LP learned Farkas constraints 0',
#  'c LP basis resets 0',
#  'c LP cycling count 0',
#  'c LP singular count 0',
#  'c LP no primal count 0',
#  'c LP no farkas count 0',
#  'c LP other issue count 0',
#  'c LP Gomory cuts 0',
#  'c LP learned cuts 0',
#  'c LP deleted cuts 0',
#  'c LP encountered Gomory constraints 0',
#  'c LP encountered Farkas constraints 0',
#  'c LP encountered learned Farkas constraints 0',
#  's UNKNOWN']

# %%
presolveout
# Out:
# ['Filename in given: ../test/cracpb1.0.s.opb Filename out given: ../testPre/pre.cracpb1.0.s.opb',
#  'Parsing ...',
#  '  Parser found: 572 vars',
#  '  Parser found: 145 constraints',
#  'Done!',
#  '',
#  'starting presolve of problem ../test/cracpb1.0.s.opb:',
#  '  rows:     145',
#  '  columns:  572 (572 int., 0 cont.)',
#  '  nonzeros: 5248',
#  '',
#  'round 0   ( Trivial  ):    0 del cols,   18 del rows,    0 chg bounds,    0 chg sides,    0 chg coeffs,    0 tsx applied,    0 tsx conflicts',
#  'round 1   (Exhaustive): Unchanged',
#  'activating delayed presolvers',
#  'round 2   (Exhaustive):    0 del cols,   18 del rows,    0 chg bounds,  184 chg sides, 2179 chg coeffs,   89 tsx applied,    4 tsx conflicts',
#  'round 3   (Exhaustive):    2 del cols,   18 del rows,    2 chg bounds,  184 chg sides, 2179 chg coeffs,   91 tsx applied,    6 tsx conflicts',
#  'round 4   (Exhaustive):    2 del cols,   18 del rows,    2 chg bounds,  185 chg sides, 2282 chg coeffs,   98 tsx applied,    8 tsx conflicts',
#  'round 5   (  Final   ): Unchanged',
#  'presolved 5 rounds:    2 del cols,   18 del rows,    2 chg bounds,  185 chg sides, 2282 chg coeffs,   98 tsx applied,   10 tsx conflicts',
#  '',
#  '          presolver     nb calls   success calls(%)    nb transactions     tsx applied(%)  execution time(s) ',
#  '       colsingleton            5                0.0                  0                0.0              0.000',
#  '    coefftightening            5                0.0                  0                0.0              0.000',
#  '        propagation            5                0.0                  0                0.0              0.000',
#  '      simpleprobing            2                0.0                  0                0.0              0.000',
#  '           stuffing            2                0.0                  0                0.0              0.000',
#  '            dualfix            2                0.0                  0                0.0              0.000',
#  '      fixcontinuous            0                0.0                  0                0.0              0.000',
#  '       parallelrows            0                0.0                  0                0.0              0.000',
#  '       parallelcols            0                0.0                  0                0.0              0.000',
#  '        doubletoneq            2                0.0                  0                0.0              0.000',
#  '       simplifyineq            2                0.0                  0                0.0              0.001',
#  '            implint            0                0.0                  0                0.0              0.000',
#  '          dualinfer            0                0.0                  0                0.0              0.000',
#  '       substitution            5              100.0                 10                0.0              0.005',
#  '            probing            3               33.3                  2              100.0              0.007',
#  '             domcol            2                0.0                  0                0.0              0.001',
#  '           sparsify            2              100.0                 96              100.0              0.001',
#  '',
#  'presolved problem:',
#  '  rows:     127',
#  '  columns:  570 (570 int., 0 cont.)',
#  '  nonzeros: 3967',
#  'Status code of test problem: 1',
#  '        0.40 real         0.08 user         0.02 sys']

# %%
presolveres
# Out:
# ['c RoundingSat 2',
#  'c branch master',
#  'c commit 1476bf0',
#  'c #variables 570 #constraints 216',
#  'c #Conflicts:       1000 | #Constraints:       1215',
#  'c #Conflicts:       2000 | #Constraints:       2215',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:       3000 | #Constraints:       2063',
#  'c #Conflicts:       4000 | #Constraints:       3063',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:       5000 | #Constraints:       2157',
#  'c #Conflicts:       6000 | #Constraints:       3157',
#  'c #Conflicts:       7000 | #Constraints:       4157',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c #Conflicts:       8000 | #Constraints:       2735',
#  'c #Conflicts:       9000 | #Constraints:       3735',
#  'c #Conflicts:      10000 | #Constraints:       4735',
#  'c #Conflicts:      11000 | #Constraints:       5735',
#  'c INPROCESSING',
#  'c GARBAGE COLLECT',
#  'c cpu time 4.66832 s',
#  'c deterministic time 604177130 6.04e+08',
#  'c optimization time 2e-05 s',
#  'c total solve time 4.66586 s',
#  'c propagation time 3.59016 s',
#  'c conflict analysis time 0.904553 s',
#  'c propagations 701212',
#  'c resolve steps 39919',
#  'c decisions 90214',
#  'c conflicts 11695',
#  'c restarts 50',
#  'c inprocessing phases 4',
#  'c input clauses 58',
#  'c input cardinalities 153',
#  'c input general constraints 5',
#  'c input average constraint length 26.52',
#  'c input average constraint degree 1346.76',
#  'c learned clauses 730',
#  'c learned cardinalities 208',
#  'c learned general constraints 10756',
#  'c learned average constraint length 191.33',
#  'c learned average constraint degree 63993.29',
#  'c watched constraints 4516',
#  'c counting constraints 6245',
#  'c gcd simplifications 44',
#  'c detected cardinalities 5',
#  'c weakened non-implied lits 533026',
#  'c weakened non-implying lits 1122',
#  'c original variables 570',
#  'c clausal propagations 17478',
#  'c cardinality propagations 243458',
#  'c watched propagations 43080',
#  'c counting propagations 376704',
#  'c watch lookups 117001676',
#  'c watch backjump lookups 114505627',
#  'c watch checks 157576259',
#  'c propagation checks 206681607',
#  'c constraint additions 6817614',
#  'c trail pops 802920',
#  'c formula constraints 216',
#  'c learned constraints 11694',
#  'c bound constraints 0',
#  'c encountered formula constraints 17052',
#  'c encountered learned constraints 34562',
#  'c encountered bound constraints 0',
#  'c LP total time 0 s',
#  'c LP solve time 0 s',
#  'c LP constraints added 0',
#  'c LP constraints removed 0',
#  'c LP pivots internal 0',
#  'c LP pivots root 0',
#  'c LP calls 0',
#  'c LP optimalities 0',
#  'c LP no pivot count 0',
#  'c LP infeasibilities 0',
#  'c LP valid Farkas constraints 0',
#  'c LP learned Farkas constraints 0',
#  'c LP basis resets 0',
#  'c LP cycling count 0',
#  'c LP singular count 0',
#  'c LP no primal count 0',
#  'c LP no farkas count 0',
#  'c LP other issue count 0',
#  'c LP Gomory cuts 0',
#  'c LP learned cuts 0',
#  'c LP deleted cuts 0',
#  'c LP encountered Gomory constraints 0',
#  'c LP encountered Farkas constraints 0',
#  'c LP encountered learned Farkas constraints 0',
#  's UNSATISFIABLE',
#  '        4.83 real         4.66 user         0.11 sys']
